# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load data
import pandas as pd
df=pd.read_csv('/content/drive/My Drive/Tenx/Week 5/data.csv')

# %%
# Overview of the Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95662 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  object
#  14  PricingStrategy       95662 non-null  int64
# ...

# %%
df['CurrencyCode'].unique()
df['CountryCode'].unique()
df['ProductCategory'].unique()
df['ChannelId'].unique()
df['PricingStrategy'].unique()
# Out:
# array([2, 4, 1, 0])

# %%
# Train-test split
from sklearn.model_selection import train_test_split
train, test= train_test_split(df, test_size=0.2, random_state=42)

# %%
# Import Script
import Feature_Eng
import importlib
importlib.reload(Feature_Eng)
# Out:
# <module 'Feature_Eng' from '/content/Feature_Eng.py'>

# %%
Feature_Eng.pipe[0]
# Out:
# FeatureAdder(funcs=[functools.partial(<function Aggregate_Features at 0x7b3f80f92ca0>, col1='CustomerId', col2='Amount'),
#                     functools.partial(<function get_time at 0x7b3f80f932e0>, col='TransactionStartTime'),
#                     functools.partial(<function label_encode at 0x7b3f80f911c0>, col='ProductCategory'),
#                     functools.partial(<function label_encode at 0x7b3f80f911c0>, col='ChannelId'),
#                     functools.partial(<function scaler at 0x7b3f80f916c0>),
#                     functools.partial(<function missing_values at 0x7b3f80f93240>)])

# %%
#Create Aggregate Features, Extract Features from Time, Encode Categorical Variables for train data, Scale data and deal with missing values
train=Feature_Eng.pipe[0].fit_transform(train)

# %%
train
# Out:
#               TransactionId         BatchId       AccountId  \
# 0      TransactionId_140210    BatchId_5730  AccountId_4841
# 1      TransactionId_121349    BatchId_3209  AccountId_1270
# 2      TransactionId_128133  BatchId_127344  AccountId_1796
# 3       TransactionId_93768   BatchId_13153  AccountId_4841
# 4       TransactionId_36333   BatchId_15503  AccountId_2659
# ...                     ...             ...             ...
# 76524  TransactionId_130267   BatchId_18840  AccountId_4416
# 76525   TransactionId_62282   BatchId_35334   AccountId_318
# 76526  TransactionId_117613  BatchId_106834  AccountId_2972
# 76527   TransactionId_78299   BatchId_35778    AccountId_10
# 76528   TransactionId_21102  BatchId_101918  AccountId_4249
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0      SubscriptionId_3829  CustomerId_4312          UGX          256
# 1      SubscriptionId_4526  CustomerId_1632          UGX          256
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76529 entries, 0 to 76528
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TransactionId            76529 non-null  object
#  1   BatchId                  76529 non-null  object
#  2   AccountId                76529 non-null  object
#  3   SubscriptionId           76529 non-null  object
#  4   CustomerId               76529 non-null  object
#  5   CurrencyCode             76529 non-null  object
#  6   CountryCode              76529 non-null  int64
#  7   ProviderId               76529 non-null  object
#  8   ProductId                76529 non-null  object
#  9   ProductCategory          76529 non-null  object
#  10  ChannelId                76529 non-null  object
#  11  Amount                   76529 non-null  float64
#  12  Value                    76529 non-null  float64
# ...

# %%
train.to_csv('cleaned.csv', index=False)

# %%
#Export test data
test=Feature_Eng.pipe[0].fit_transform(test)

# %%
test.to_csv("test.csv",index=False)
